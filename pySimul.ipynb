# %%
from utils.synthesis_data import create_ads_spend, create_baseline, define_basic_parameters, generate_media
from utils.synthesis_data import generate_noisy_cvr, pivot_to_mmm_format, apply_adstock, apply_diminishing_returns, calculate_conversions, generate_final_df
from utils.plot_helpers import plot_baseline_sales, plot_ads_spend, plot_channel_transforms, plot_actual_vs_self_conversions
import os

# %% [markdown]
# # Define Basic Parameters

# %%
years = 2
channels_impressions = ["Programmatic", "Google.SEM", "TikTok", "SEO.Non.Brand", "Facebook", "CRM", "Affiliates"]
channels_sessions = ["Direct", "Unassigned"]
channels_clicks = []
frequency_of_campaigns = 1
true_cvr = [0.001, 0.01, 0.003, 0.002, 0.005, 0.004, 0.006, 0.007, 0.003]
revenue_per_conv = 1.0
start_date = "2020/1/1"

basic_parameters = define_basic_parameters(
            years=years,
            channels_impressions=channels_impressions,
            channels_sessions=channels_sessions,
            frequency_of_campaigns=frequency_of_campaigns,
            true_cvr=true_cvr,
            revenue_per_conv=revenue_per_conv,
            start_date=start_date
        )
# Out:
# ***** Defining Basic Parameters *****
# | Parameter                 | Value                                                                      |
# |---------------------------|----------------------------------------------------------------------------|
# | Years of Data to generate | 2                                                                          |
# | Channels (impressions)    | Programmatic, Google.SEM, TikTok, SEO.Non.Brand, Facebook, CRM, Affiliates |
# | Channels (clicks)         |                                                                            |
# | Channels (sessions)       | Direct, Unassigned                                                         |
# | Campaign frequency        | 1                                                                          |
# | True CVRs                 | 0.001, 0.01, 0.003, 0.002, 0.005, 0.004, 0.006, 0.007, 0.003               |
# | Revenue per conversion    | 1.0                                                                        |
# | Start date                | 2020-01-01                                                                 |

# %%
basic_parameters
# Out:
# {'years': 2,
#  'channels_impressions': ['Programmatic',
#   'Google.SEM',
#   'TikTok',
#   'SEO.Non.Brand',
#   'Facebook',
#   'CRM',
#   'Affiliates'],
#  'channels_clicks': [],
#  'channels_sessions': ['Direct', 'Unassigned'],
#  'frequency_of_campaigns': 1,
#  'true_cvr': [0.001, 0.01, 0.003, 0.002, 0.005, 0.004, 0.006, 0.007, 0.003],
#  'revenue_per_conv': 1.0,
#  'start_date': datetime.date(2020, 1, 1)}

# %% [markdown]
# # Simulate Daily Baseline Sales

# %% [markdown]
# Tips on Picking Parameters:
#
# * How to select `base_p` and `trend_p`?: To reflect your business scenario, you can look at your own business's historical data or more aggregate data on the growth of your industry over time. You can play with this number to generate a variety of data sets and see how MMMs react to changes in base_p and trend_p.
#
# * How can I pick a temp_coef_mean?: Play around with this and the other variables. The larger this number is, the more seasonality will have an impact on your data.

# %%
df_baseline = create_baseline(
                setup_variables = basic_parameters,
                base_p = 500000,
                trend_p = 1.8,
                temp_var = 8,
                temp_coef_mean = 50000,
                temp_coef_sd = 5000,
                error_std = 100000)
# Out:
# Generating baseline sales: Done!
#
# Descriptive statistics:
#                 count          mean            std            min  \
# day             730.0  3.655000e+02     210.877136       1.000000
# baseline_sales  730.0  9.485489e+05  286416.290773  280975.966072
# base            730.0  5.000000e+05       0.000000  500000.000000
# trend           730.0  4.506164e+05  259985.510661    1232.876712
# temp            730.0 -1.557354e-16       5.660733      -7.999926
# seasonality     730.0  0.000000e+00  222870.865023 -314968.127768
# error           730.0 -2.067537e+03  100064.462373 -329235.185016
#
#                           25%           50%           75%           max
# day                183.250000  3.655000e+02  5.477500e+02  7.300000e+02
# baseline_sales  719559.020376  9.531372e+05  1.168603e+06  1.665495e+06
# base            500000.000000  5.000000e+05  5.000000e+05  5.000000e+05
# trend           225924.657534  4.506164e+05  6.753082e+05  9.000000e+05
# temp                -5.644669  7.718989e-15  5.644669e+00  7.999926e+00
# seasonality    -222238.406646  3.039072e-10  2.222384e+05  3.149681e+05
# error           -69913.348911  3.930479e+02  6.216760e+04  3.211588e+05

# %%
plot_baseline_sales(df_baseline, figsize=(900, 600))

# %% [markdown]
# # Generate Ad Spend

# %%
min_max_proportion = {
    "Programmatic": (0.15, 0.20),
    "Google.SEM": (0.25, 0.55),
    "TikTok": (0.10, 0.20),
    "SEO.Non.Brand": (0.05, 0.15),
    "Facebook": (0.15, 0.35),
    "CRM": (0.05, 0.10),
    "Affiliates": (0.02, 0.08),
    "Direct": (0, 0),  
    # last channel 'Unassigned' will get remainder
}

df_spend = create_ads_spend(
    setup_variables=basic_parameters,
    campaign_spend_mean=329000,
    campaign_spend_std=100000,
    min_max_proportion=min_max_proportion
)

df_spend.head()
# Out:
# Simulated ad spend: Done!
#          day        channel channel_type  total_campaign_spend  \
# 0 2020-01-01   Programmatic  impressions         423786.450689
# 1 2020-01-01     Google.SEM  impressions         330376.793748
# 2 2020-01-01         TikTok  impressions         308881.220922
# 3 2020-01-01  SEO.Non.Brand  impressions         195784.601738
# 4 2020-01-01       Facebook  impressions         239954.933343
#
#    channel_prop_spend  spend_channel
# 0            0.164744   69816.246041
# 1            0.344226  113724.328341
# 2            0.183571   56701.495129
# 3            0.064021   12534.300947
# 4            0.344274   82610.183601

# %%
# Per-channel spend
# Line chart (default)
plot_ads_spend(df_spend, by="channel", chart_type="line", figsize=(900, 600))

# %%
# Bar chart
plot_ads_spend(df_spend, by="channel", chart_type="pie", figsize=(900, 600))

# %%
# Total spend
plot_ads_spend(df_spend, by="total", figsize=(900, 600))

# %% [markdown]
# # Generate Media Variables

# %% [markdown]
# Tips on Picking Parameters:
#
# * How do you pick `true_cpm` and `true_cpc`? We recommend you use historical data as a starting point. Figure out the average CPMs and CPCs on campaigns that you've run in the past. You can also play around with these numbers to see how MMMs react upon changing these numbers.

# %%
true_cpm = {
    "Programmatic": 2,
    "Google.SEM": 20,
    "TikTok": 10,
    "SEO.Non.Brand": 5,
    "Facebook": 15,
    "CRM": 30,
    "Affiliates": 8,
    "Direct": None,  # Direct does not have CPM
    "Unassigned": None  # Unassigned does not have CPM
}

# true_cpc = {
#     "Facebook": 0.25,
#     "CRM": 0.50
# }

mean_noisy = {
    "Programmatic": 0.01,
    "Google.SEM": 0.05,
    "TikTok": 0.03,
    "Facebook": 0.04,
    "CRM": 0.05,
    "SEO.Non.Brand": 0.02,
    "Direct": 0.06,
    "Unassigned": 0.05,
    "Affiliates": 0.02
}

std_noisy = {
    "Programmatic": 0.005,
    "Google.SEM": 0.02,
    "TikTok": 0.01,
    "Facebook": 0.02,
    "CRM": 0.03,
    "SEO.Non.Brand": 0.01,
    "Direct": 0.03,
    "Unassigned": 0.02,
    "Affiliates": 0.01
}

# --------------------------
# Define session configs
# --------------------------
sessions_config = {
    "Direct": {
        "base_sessions": 10000,
        "trend_per_year": 0.05,
        "weekly_strength": 0.12,
        "annual_strength": 0.15,
        "noise_cv": 0.08
    },
    "Unassigned": {
        "base_sessions": 5000,
        "trend_per_year": 0.03,
        "weekly_strength": 0.10,
        "annual_strength": 0.12,
        "noise_cv": 0.06
    }
}

# Run
df_media = generate_media(
    setup_variables=basic_parameters,
    df_ads_spends=df_spend,
    true_cpm=true_cpm,
    true_cpc={},
    mean_noisy=mean_noisy,
    std_noisy=std_noisy,
    sessions_config=sessions_config
)
# Out:
# Simulating media variables: Done!

# %%
df_media.columns
# Out:
# Index(['day', 'channel', 'channel_type', 'total_campaign_spend',
#        'channel_prop_spend', 'spend_channel', 'campaign_id', 'true_cpm',
#        'noisy_cpm', 'true_cpc', 'noisy_cpc', 'lifetime_impressions',
#        'lifetime_clicks', 'lifetime_sessions',
#        'impressions_Programmatic_after_running_day_1',
#        'impressions_Google.SEM_after_running_day_1',
#        'impressions_TikTok_after_running_day_1',
#        'impressions_SEO.Non.Brand_after_running_day_1',
#        'impressions_Facebook_after_running_day_1',
#        'impressions_CRM_after_running_day_1',
#        'impressions_Affiliates_after_running_day_1',
#        'sessions_Direct_after_running_day_1',
#        'sessions_Unassigned_after_running_day_1',
#        'spend_Programmatic_after_running_day_1',
#        'spend_Google.SEM_after_running_day_1',
#        'spend_TikTok_after_running_day_1',
#        'spend_SEO.Non.Brand_after_running_day_1',
#        'spend_Facebook_after_running_day_1', 'spend_CRM_after_running_day_1',
#        'spend_Affiliates_after_running_day_1',
#        'spend_Direct_after_running_day_1',
#        'spend_Unassigned_after_running_day_1'],
#       dtype='object')

# %% [markdown]
# # Generate Noisy CVRs

# %%
# Optional noise (defaults to 0 if omitted)

mean_noisy_cvr = {
    "Programmatic": 0.002,
    "Google.SEM":  0.01,
    "TikTok":      0.003,
    "Facebook":    0.0015,
    "CRM":         0.0002,
    "Direct":      0.004,
    "Unassigned":  0.0055,
}
std_noisy_cvr = {
    "Programmatic": 0.001,
    "Google.SEM":   0.002,
    "TikTok":       0.003,
    "Facebook":     0.001,
    "CRM":          0.002,
    "Direct":       0.001,
    "Unassigned":   0.0015,
}

df_ads = generate_noisy_cvr(
    setup_variables=basic_parameters,
    df_media=df_media,
    mean_noisy_cvr=mean_noisy_cvr,
    std_noisy_cvr=std_noisy_cvr
)
# Out:
# You have completed running step 4: Simulating conversion rates.

# %%
df_ads.filter(regex=r"_cvr_")
# Out:
#       noisy_cvr_Affiliates_after_running_day_1  \
# 0                                        0.000
# 1                                        0.000
# 2                                        0.000
# 3                                        0.000
# 4                                        0.000
# ...                                        ...
# 6565                                     0.000
# 6566                                     0.000
# 6567                                     0.006
# 6568                                     0.000
# 6569                                     0.000
#
#       noisy_cvr_SEO.Non.Brand_after_running_day_1  \
# 0                                           0.000
# 1                                           0.000
# 2                                           0.000
# 3                                           0.002
# 4                                           0.000
# ...                                           ...
# 6565                                        0.000
# 6566                                        0.000
# 6567                                        0.000
# 6568                                        0.000
# 6569                                        0.000
#
#       noisy_cvr_Google.SEM_after_running_day_1  \
# 0                                     0.000000
# 1                                     0.021271
# 2                                     0.000000
# 3                                     0.000000
# 4                                     0.000000
# ...                                        ...
# 6565                                  0.000000
# 6566                                  0.000000
# 6567                                  0.000000
# 6568                                  0.000000
# 6569                                  0.000000
#
#       noisy_cvr_Unassigned_after_running_day_1  \
# 0                                     0.000000
# 1                                     0.000000
# 2                                     0.000000
# 3                                     0.000000
# 4                                     0.000000
# ...                                        ...
# 6565                                  0.000000
# 6566                                  0.000000
# 6567                                  0.000000
# 6568                                  0.000000
# 6569                                  0.009626
#
#       noisy_cvr_TikTok_after_running_day_1  \
# 0                                 0.000000
# 1                                 0.000000
# 2                                 0.006831
# 3                                 0.000000
# 4                                 0.000000
# ...                                    ...
# 6565                              0.000000
# 6566                              0.000000
# 6567                              0.000000
# 6568                              0.000000
# 6569                              0.000000
#
#       noisy_cvr_Direct_after_running_day_1  noisy_cvr_CRM_after_running_day_1  \
# 0                                 0.000000                           0.000000
# 1                                 0.000000                           0.000000
# 2                                 0.000000                           0.000000
# 3                                 0.000000                           0.000000
# 4                                 0.000000                           0.000000
# ...                                    ...                                ...
# 6565                              0.000000                           0.000000
# 6566                              0.000000                           0.005558
# 6567                              0.000000                           0.000000
# 6568                              0.010982                           0.000000
# 6569                              0.000000                           0.000000
#
#       noisy_cvr_Programmatic_after_running_day_1  \
# 0                                       0.002933
# 1                                       0.000000
# 2                                       0.000000
# 3                                       0.000000
# 4                                       0.000000
# ...                                          ...
# 6565                                    0.000000
# 6566                                    0.000000
# 6567                                    0.000000
# 6568                                    0.000000
# 6569                                    0.000000
#
#       noisy_cvr_Facebook_after_running_day_1
# 0                                   0.000000
# 1                                   0.000000
# 2                                   0.000000
# 3                                   0.000000
# 4                                   0.005060
# ...                                      ...
# 6565                                0.006594
# 6566                                0.000000
# 6567                                0.000000
# 6568                                0.000000
# 6569                                0.000000
#
# [6570 rows x 9 columns]

# %%
df_ads.head(10)
# Out:
#          day        channel channel_type  total_campaign_spend  \
# 0 2020-01-01   Programmatic  impressions         423786.450689
# 1 2020-01-01     Google.SEM  impressions         330376.793748
# 2 2020-01-01         TikTok  impressions         308881.220922
# 3 2020-01-01  SEO.Non.Brand  impressions         195784.601738
# 4 2020-01-01       Facebook  impressions         239954.933343
# 5 2020-01-01            CRM  impressions         419226.447718
# 6 2020-01-01     Affiliates  impressions         146213.971993
# 7 2020-01-01         Direct     sessions         319401.532771
# 8 2020-01-01     Unassigned     sessions         262968.164201
# 9 2020-01-02   Programmatic  impressions         299315.795950
#
#    channel_prop_spend  spend_channel  campaign_id  true_cpm  noisy_cpm  \
# 0            0.164744   69816.246041            1       2.0   2.009463
# 1            0.344226  113724.328341            1      20.0  20.095766
# 2            0.183571   56701.495129            1      10.0  10.027108
# 3            0.064021   12534.300947            1       5.0   5.013289
# 4            0.344274   82610.183601            1      15.0  15.021502
# 5            0.089740   37621.433854            1      30.0  30.049083
# 6            0.024849    3633.300596            1       8.0   8.010120
# 7            0.000000       0.000000            1       NaN        NaN
# 8            0.000000       0.000000            1       NaN        NaN
# 9            0.165139   49428.733531            2       2.0   2.003231
#
#    true_cpc  ...  noisy_cvr  noisy_cvr_Affiliates_after_running_day_1  \
# 0       NaN  ...   0.002933                                     0.000
# 1       NaN  ...   0.021271                                     0.000
# 2       NaN  ...   0.006831                                     0.000
# 3       NaN  ...   0.002000                                     0.000
# 4       NaN  ...   0.005060                                     0.000
# 5       NaN  ...   0.001900                                     0.000
# 6       NaN  ...   0.006000                                     0.006
# 7       NaN  ...   0.010037                                     0.000
# 8       NaN  ...   0.007873                                     0.000
# 9       NaN  ...   0.004294                                     0.000
#
#    noisy_cvr_SEO.Non.Brand_after_running_day_1  \
# 0                                        0.000
# 1                                        0.000
# 2                                        0.000
# 3                                        0.002
# 4                                        0.000
# 5                                        0.000
# 6                                        0.000
# 7                                        0.000
# 8                                        0.000
# 9                                        0.000
#
#    noisy_cvr_Google.SEM_after_running_day_1  \
# 0                                  0.000000
# 1                                  0.021271
# 2                                  0.000000
# 3                                  0.000000
# 4                                  0.000000
# 5                                  0.000000
# 6                                  0.000000
# 7                                  0.000000
# 8                                  0.000000
# 9                                  0.000000
#
#    noisy_cvr_Unassigned_after_running_day_1  \
# 0                                  0.000000
# 1                                  0.000000
# 2                                  0.000000
# 3                                  0.000000
# 4                                  0.000000
# 5                                  0.000000
# 6                                  0.000000
# 7                                  0.000000
# 8                                  0.007873
# 9                                  0.000000
#
#    noisy_cvr_TikTok_after_running_day_1  noisy_cvr_Direct_after_running_day_1  \
# 0                              0.000000                              0.000000
# 1                              0.000000                              0.000000
# 2                              0.006831                              0.000000
# 3                              0.000000                              0.000000
# 4                              0.000000                              0.000000
# 5                              0.000000                              0.000000
# 6                              0.000000                              0.000000
# 7                              0.000000                              0.010037
# 8                              0.000000                              0.000000
# 9                              0.000000                              0.000000
#
#    noisy_cvr_CRM_after_running_day_1  \
# 0                             0.0000
# 1                             0.0000
# 2                             0.0000
# 3                             0.0000
# 4                             0.0000
# 5                             0.0019
# 6                             0.0000
# 7                             0.0000
# 8                             0.0000
# 9                             0.0000
#
#    noisy_cvr_Programmatic_after_running_day_1  \
# 0                                    0.002933
# 1                                    0.000000
# 2                                    0.000000
# 3                                    0.000000
# 4                                    0.000000
# 5                                    0.000000
# 6                                    0.000000
# 7                                    0.000000
# 8                                    0.000000
# 9                                    0.004294
#
#    noisy_cvr_Facebook_after_running_day_1
# 0                                 0.00000
# 1                                 0.00000
# 2                                 0.00000
# 3                                 0.00000
# 4                                 0.00506
# 5                                 0.00000
# 6                                 0.00000
# 7                                 0.00000
# 8                                 0.00000
# 9                                 0.00000
#
# [10 rows x 43 columns]

# %%
df_ads.columns
# Out:
# Index(['day', 'channel', 'channel_type', 'total_campaign_spend',
#        'channel_prop_spend', 'spend_channel', 'campaign_id', 'true_cpm',
#        'noisy_cpm', 'true_cpc', 'noisy_cpc', 'lifetime_impressions',
#        'lifetime_clicks', 'lifetime_sessions',
#        'impressions_Programmatic_after_running_day_1',
#        'impressions_Google.SEM_after_running_day_1',
#        'impressions_TikTok_after_running_day_1',
#        'impressions_SEO.Non.Brand_after_running_day_1',
#        'impressions_Facebook_after_running_day_1',
#        'impressions_CRM_after_running_day_1',
#        'impressions_Affiliates_after_running_day_1',
#        'sessions_Direct_after_running_day_1',
#        'sessions_Unassigned_after_running_day_1',
#        'spend_Programmatic_after_running_day_1',
#        'spend_Google.SEM_after_running_day_1',
#        'spend_TikTok_after_running_day_1',
#        'spend_SEO.Non.Brand_after_running_day_1',
#        'spend_Facebook_after_running_day_1', 'spend_CRM_after_running_day_1',
#        'spend_Affiliates_after_running_day_1',
#        'spend_Direct_after_running_day_1',
#        'spend_Unassigned_after_running_day_1', 'true_cvr', 'noisy_cvr',
#        'noisy_cvr_Affiliates_after_running_day_1',
#        'noisy_cvr_SEO.Non.Brand_after_running_day_1',
#        'noisy_cvr_Google.SEM_after_running_day_1',
#        'noisy_cvr_Unassigned_after_running_day_1',
#        'noisy_cvr_TikTok_after_running_day_1',
#        'noisy_cvr_Direct_after_running_day_1',
#        'noisy_cvr_CRM_after_running_day_1',
#        'noisy_cvr_Programmatic_after_running_day_1',
#        'noisy_cvr_Facebook_after_running_day_1'],
#       dtype='object')

# %%
df_ads.filter(regex=r"^(impressions_|sessions_)").head(20)
# Out:
#     impressions_Programmatic_after_running_day_1  \
# 0                                   3.474373e+07
# 1                                   0.000000e+00
# 2                                   0.000000e+00
# 3                                   0.000000e+00
# 4                                   0.000000e+00
# 5                                   0.000000e+00
# 6                                   0.000000e+00
# 7                                   0.000000e+00
# 8                                   0.000000e+00
# 9                                   2.467451e+07
# 10                                  0.000000e+00
# 11                                  0.000000e+00
# 12                                  0.000000e+00
# 13                                  0.000000e+00
# 14                                  0.000000e+00
# 15                                  0.000000e+00
# 16                                  0.000000e+00
# 17                                  0.000000e+00
# 18                                  2.206128e+07
# 19                                  0.000000e+00
#
#     impressions_Google.SEM_after_running_day_1  \
# 0                                 0.000000e+00
# 1                                 5.659119e+06
# 2                                 0.000000e+00
# 3                                 0.000000e+00
# 4                                 0.000000e+00
# 5                                 0.000000e+00
# 6                                 0.000000e+00
# 7                                 0.000000e+00
# 8                                 0.000000e+00
# 9                                 0.000000e+00
# 10                                7.259378e+06
# 11                                0.000000e+00
# 12                                0.000000e+00
# 13                                0.000000e+00
# 14                                0.000000e+00
# 15                                0.000000e+00
# 16                                0.000000e+00
# 17                                0.000000e+00
# 18                                0.000000e+00
# 19                                3.674833e+06
#
#     impressions_TikTok_after_running_day_1  \
# 0                             0.000000e+00
# 1                             0.000000e+00
# 2                             5.654821e+06
# 3                             0.000000e+00
# 4                             0.000000e+00
# 5                             0.000000e+00
# 6                             0.000000e+00
# 7                             0.000000e+00
# 8                             0.000000e+00
# 9                             0.000000e+00
# 10                            0.000000e+00
# 11                            5.200713e+06
# 12                            0.000000e+00
# 13                            0.000000e+00
# 14                            0.000000e+00
# 15                            0.000000e+00
# 16                            0.000000e+00
# 17                            0.000000e+00
# 18                            0.000000e+00
# 19                            0.000000e+00
#
#     impressions_SEO.Non.Brand_after_running_day_1  \
# 0                                    0.000000e+00
# 1                                    0.000000e+00
# 2                                    0.000000e+00
# 3                                    2.500215e+06
# 4                                    0.000000e+00
# 5                                    0.000000e+00
# 6                                    0.000000e+00
# 7                                    0.000000e+00
# 8                                    0.000000e+00
# 9                                    0.000000e+00
# 10                                   0.000000e+00
# 11                                   0.000000e+00
# 12                                   7.901119e+06
# 13                                   0.000000e+00
# 14                                   0.000000e+00
# 15                                   0.000000e+00
# 16                                   0.000000e+00
# 17                                   0.000000e+00
# 18                                   0.000000e+00
# 19                                   0.000000e+00
#
#     impressions_Facebook_after_running_day_1  \
# 0                               0.000000e+00
# 1                               0.000000e+00
# 2                               0.000000e+00
# 3                               0.000000e+00
# 4                               5.499462e+06
# 5                               0.000000e+00
# 6                               0.000000e+00
# 7                               0.000000e+00
# 8                               0.000000e+00
# 9                               0.000000e+00
# 10                              0.000000e+00
# 11                              0.000000e+00
# 12                              0.000000e+00
# 13                              4.305324e+06
# 14                              0.000000e+00
# 15                              0.000000e+00
# 16                              0.000000e+00
# 17                              0.000000e+00
# 18                              0.000000e+00
# 19                              0.000000e+00
#
#     impressions_CRM_after_running_day_1  \
# 0                          0.000000e+00
# 1                          0.000000e+00
# 2                          0.000000e+00
# 3                          0.000000e+00
# 4                          0.000000e+00
# 5                          1.251999e+06
# 6                          0.000000e+00
# 7                          0.000000e+00
# 8                          0.000000e+00
# 9                          0.000000e+00
# 10                         0.000000e+00
# 11                         0.000000e+00
# 12                         0.000000e+00
# 13                         0.000000e+00
# 14                         1.042125e+06
# 15                         0.000000e+00
# 16                         0.000000e+00
# 17                         0.000000e+00
# 18                         0.000000e+00
# 19                         0.000000e+00
#
#     impressions_Affiliates_after_running_day_1  \
# 0                                 0.000000e+00
# 1                                 0.000000e+00
# 2                                 0.000000e+00
# 3                                 0.000000e+00
# 4                                 0.000000e+00
# 5                                 0.000000e+00
# 6                                 4.535888e+05
# 7                                 0.000000e+00
# 8                                 0.000000e+00
# 9                                 0.000000e+00
# 10                                0.000000e+00
# 11                                0.000000e+00
# 12                                0.000000e+00
# 13                                0.000000e+00
# 14                                0.000000e+00
# 15                                2.952186e+06
# 16                                0.000000e+00
# 17                                0.000000e+00
# 18                                0.000000e+00
# 19                                0.000000e+00
#
#     sessions_Direct_after_running_day_1  \
# 0                              0.000000
# 1                              0.000000
# 2                              0.000000
# 3                              0.000000
# 4                              0.000000
# 5                              0.000000
# 6                              0.000000
# 7                          11595.747425
# 8                              0.000000
# 9                              0.000000
# 10                             0.000000
# 11                             0.000000
# 12                             0.000000
# 13                             0.000000
# 14                             0.000000
# 15                             0.000000
# 16                         11631.900390
# 17                             0.000000
# 18                             0.000000
# 19                             0.000000
#
#     sessions_Unassigned_after_running_day_1
# 0                                  0.000000
# 1                                  0.000000
# 2                                  0.000000
# 3                                  0.000000
# 4                                  0.000000
# 5                                  0.000000
# 6                                  0.000000
# 7                                  0.000000
# 8                              10490.666620
# 9                                  0.000000
# 10                                 0.000000
# 11                                 0.000000
# 12                                 0.000000
# 13                                 0.000000
# 14                                 0.000000
# 15                                 0.000000
# 16                                 0.000000
# 17                              9884.142587
# 18                                 0.000000
# 19                                 0.000000

# %% [markdown]
# # Transforming Media Variables

# %% [markdown]
# ## Pivoting the table to an MMM format

# %%
df_before_mmm = pivot_to_mmm_format(
    setup_variables=basic_parameters,
    df_ads=df_ads
)
# Out:
# Pivoting the data frame to an MMM format: Done!

# %%
df_before_mmm.head(20)
# Out:
#          DATE  sum_n_Programmatic_imps_this_day  \
# 0  2020-01-01                      3.474373e+07
# 1  2020-01-02                      2.467451e+07
# 2  2020-01-03                      2.206128e+07
# 3  2020-01-04                      2.380538e+07
# 4  2020-01-05                      4.161635e+07
# 5  2020-01-06                      2.292335e+07
# 6  2020-01-07                      1.862165e+07
# 7  2020-01-08                      2.128860e+07
# 8  2020-01-09                      2.114766e+07
# 9  2020-01-10                      1.940034e+07
# 10 2020-01-11                      4.125858e+07
# 11 2020-01-12                      4.469070e+07
# 12 2020-01-13                      3.979100e+07
# 13 2020-01-14                      4.104748e+07
# 14 2020-01-15                      2.098022e+07
# 15 2020-01-16                      3.040218e+07
# 16 2020-01-17                      2.668037e+07
# 17 2020-01-18                      2.666297e+07
# 18 2020-01-19                      2.983925e+07
# 19 2020-01-20                      3.459214e+07
#
#     sum_n_Google.SEM_imps_this_day  sum_n_TikTok_imps_this_day  \
# 0                     5.659119e+06                5.654821e+06
# 1                     7.259378e+06                5.200713e+06
# 2                     3.674833e+06                3.042234e+06
# 3                     3.048467e+06                4.759823e+06
# 4                     6.458023e+06                8.822863e+06
# 5                     1.477637e+06                2.811217e+06
# 6                     7.000092e+06                3.611693e+06
# 7                     6.829025e+06                4.735285e+06
# 8                     6.568426e+06                3.123805e+06
# 9                     2.292169e+06                6.527652e+06
# 10                    7.396380e+06                5.378757e+06
# 11                    4.544740e+06                3.414621e+06
# 12                    9.637703e+06                4.980075e+06
# 13                    8.434306e+06                4.380458e+06
# 14                    3.687642e+06                2.941386e+06
# 15                    5.615813e+06                3.555048e+06
# 16                    7.631237e+06                5.727254e+06
# 17                    6.615394e+06                7.385522e+06
# 18                    8.518579e+06                3.416794e+06
# 19                    8.720158e+06                3.452303e+06
#
#     sum_n_SEO.Non.Brand_imps_this_day  sum_n_Facebook_imps_this_day  \
# 0                        2.500215e+06                  5.499462e+06
# 1                        7.901119e+06                  4.305324e+06
# 2                        4.773498e+06                  5.707378e+06
# 3                        5.598131e+06                  2.666085e+06
# 4                        1.107352e+07                  4.737718e+06
# 5                        9.074476e+06                  2.821642e+06
# 6                        6.375061e+06                  3.170620e+06
# 7                        7.469114e+06                  4.443435e+06
# 8                        4.323392e+06                  6.390591e+06
# 9                        4.731047e+06                  7.743996e+06
# 10                       3.434705e+06                  4.881735e+06
# 11                       9.464850e+06                  5.971008e+06
# 12                       2.996444e+06                  6.008773e+06
# 13                       9.991713e+06                  4.632604e+06
# 14                       7.252368e+06                  5.783339e+06
# 15                       9.121414e+06                  5.378091e+06
# 16                       5.838497e+06                  8.687941e+06
# 17                       6.335528e+06                  7.171039e+06
# 18                       3.797158e+06                  4.843278e+06
# 19                       5.237521e+06                  3.535266e+06
#
#     sum_n_CRM_imps_this_day  sum_n_Affiliates_imps_this_day  \
# 0              1.251999e+06                    4.535888e+05
# 1              1.042125e+06                    2.952186e+06
# 2              6.415441e+05                    8.957170e+05
# 3              9.140373e+05                    1.741163e+06
# 4              9.592756e+05                    1.729475e+06
# 5              4.717928e+05                    2.798876e+06
# 6              8.480825e+05                    3.479469e+06
# 7              9.605160e+05                    2.741408e+06
# 8              5.909253e+05                    1.722812e+06
# 9              7.964397e+05                    1.869701e+06
# 10             5.895893e+05                    2.630157e+06
# 11             5.732810e+05                    2.765676e+06
# 12             1.254721e+06                    1.211505e+06
# 13             1.062559e+06                    2.895305e+06
# 14             1.098697e+06                    2.572175e+06
# 15             4.585617e+05                    5.171852e+06
# 16             9.651248e+05                    1.938581e+06
# 17             1.535843e+06                    1.530353e+06
# 18             9.325272e+05                    4.297870e+06
# 19             7.027563e+05                    1.212622e+06
#
#     sum_n_Direct_sessions_this_day  sum_n_Unassigned_sessions_this_day  ...  \
# 0                     11595.747425                        10490.666620  ...
# 1                     11631.900390                         9884.142587  ...
# 2                     10917.796677                         8023.489039  ...
# 3                      8880.526100                         8373.874793  ...
# 4                     10228.282925                         7679.995451  ...
# 5                     11209.016321                        10561.233036  ...
# 6                     10651.099350                        11783.925991  ...
# 7                     13177.099166                        11280.950554  ...
# 8                     11613.153523                        10012.824719  ...
# 9                      8698.176051                         9883.950527  ...
# 10                    10374.110980                         9004.521551  ...
# 11                     9494.248132                         9231.458844  ...
# 12                    10265.437770                        11197.103777  ...
# 13                    12066.560267                        11408.778908  ...
# 14                    10756.840305                        12757.411298  ...
# 15                    10203.504929                        11043.834013  ...
# 16                     8205.123001                         9781.150198  ...
# 17                     8297.416584                        10460.958418  ...
# 18                     9767.842522                         9036.094313  ...
# 19                    10410.831742                         9760.398378  ...
#
#     sum_spend_Unassigned_this_day  cvr_Programmatic_this_day  \
# 0                        0.000000                   0.002933
# 1                        0.000000                   0.004294
# 2                        0.000000                   0.002499
# 3                    20870.009556                   0.003415
# 4                        0.000000                   0.003667
# 5                        0.000000                   0.004456
# 6                        0.000000                   0.003488
# 7                        0.000000                   0.003356
# 8                        0.000000                   0.001648
# 9                        0.000000                   0.002500
# 10                       0.000000                   0.001498
# 11                       0.000000                   0.003252
# 12                       0.000000                   0.003394
# 13                       0.000000                   0.005976
# 14                       0.000000                   0.005370
# 15                       0.000000                   0.002910
# 16                       0.000000                   0.004915
# 17                       0.000000                   0.003070
# 18                       0.000000                   0.002605
# 19                       0.000000                   0.003067
#
#     cvr_Google.SEM_this_day  cvr_TikTok_this_day  cvr_SEO.Non.Brand_this_day  \
# 0                  0.021271             0.006831                       0.002
# 1                  0.020190             0.000898                       0.002
# 2                  0.020061             0.005767                       0.002
# 3                  0.019625             0.008345                       0.002
# 4                  0.021851             0.006631                       0.002
# 5                  0.021786             0.001477                       0.002
# 6                  0.020994             0.004896                       0.002
# 7                  0.023008             0.007362                       0.002
# 8                  0.019311             0.006462                       0.002
# 9                  0.020345             0.004193                       0.002
# 10                 0.021652             0.004047                       0.002
# 11                 0.019864             0.003116                       0.002
# 12                 0.019030             0.011445                       0.002
# 13                 0.022953             0.000000                       0.002
# 14                 0.020730             0.009350                       0.002
# 15                 0.019812             0.006283                       0.002
# 16                 0.021277             0.001703                       0.002
# 17                 0.022154             0.006229                       0.002
# 18                 0.022774             0.006124                       0.002
# 19                 0.022497             0.007979                       0.002
#
#     cvr_Facebook_this_day  cvr_CRM_this_day  cvr_Affiliates_this_day  \
# 0                0.005060          0.001900                    0.006
# 1                0.006877          0.006761                    0.006
# 2                0.005568          0.003372                    0.006
# 3                0.005322          0.007349                    0.006
# 4                0.005691          0.003052                    0.006
# 5                0.005762          0.004310                    0.006
# 6                0.008061          0.006433                    0.006
# 7                0.006292          0.004688                    0.006
# 8                0.007698          0.004302                    0.006
# 9                0.007838          0.003719                    0.006
# 10               0.006583          0.004257                    0.006
# 11               0.005014          0.003247                    0.006
# 12               0.007107          0.004404                    0.006
# 13               0.005731          0.001565                    0.006
# 14               0.006941          0.004143                    0.006
# 15               0.006812          0.002673                    0.006
# 16               0.005990          0.005422                    0.006
# 17               0.007489          0.005628                    0.006
# 18               0.006184          0.008993                    0.006
# 19               0.006348          0.004372                    0.006
#
#     cvr_Direct_this_day  cvr_Unassigned_this_day
# 0              0.010037                 0.007873
# 1              0.011229                 0.010910
# 2              0.008940                 0.007525
# 3              0.009098                 0.008682
# 4              0.009796                 0.008717
# 5              0.010968                 0.006978
# 6              0.010435                 0.009921
# 7              0.010810                 0.012035
# 8              0.013118                 0.009406
# 9              0.010082                 0.009240
# 10             0.011190                 0.010724
# 11             0.010787                 0.008874
# 12             0.009132                 0.006785
# 13             0.012282                 0.007739
# 14             0.011458                 0.009852
# 15             0.012430                 0.010669
# 16             0.009578                 0.009390
# 17             0.012429                 0.010209
# 18             0.010243                 0.008988
# 19             0.010962                 0.009288
#
# [20 rows x 28 columns]

# %%
df_before_mmm.columns
# Out:
# Index(['DATE', 'sum_n_Programmatic_imps_this_day',
#        'sum_n_Google.SEM_imps_this_day', 'sum_n_TikTok_imps_this_day',
#        'sum_n_SEO.Non.Brand_imps_this_day', 'sum_n_Facebook_imps_this_day',
#        'sum_n_CRM_imps_this_day', 'sum_n_Affiliates_imps_this_day',
#        'sum_n_Direct_sessions_this_day', 'sum_n_Unassigned_sessions_this_day',
#        'sum_spend_Programmatic_this_day', 'sum_spend_Google.SEM_this_day',
#        'sum_spend_TikTok_this_day', 'sum_spend_SEO.Non.Brand_this_day',
#        'sum_spend_Facebook_this_day', 'sum_spend_CRM_this_day',
#        'sum_spend_Affiliates_this_day', 'sum_spend_Direct_this_day',
#        'sum_spend_Unassigned_this_day', 'cvr_Programmatic_this_day',
#        'cvr_Google.SEM_this_day', 'cvr_TikTok_this_day',
#        'cvr_SEO.Non.Brand_this_day', 'cvr_Facebook_this_day',
#        'cvr_CRM_this_day', 'cvr_Affiliates_this_day', 'cvr_Direct_this_day',
#        'cvr_Unassigned_this_day'],
#       dtype='object')

# %% [markdown]
# ## Apply Adstock

# %%
true_lambda_decay = {
    "Programmatic": 0.1,
    "Google.SEM": 0.2,
    "TikTok": 0.3,
    "SEO.Non.Brand": 0.15,
    "Facebook": 0.25,
    "CRM": 0.1,
    "Affiliates": 0.05,
    "Direct": 0.2,
    "Unassigned": 0.1
}

df_adstock = apply_adstock(
    setup_variables=basic_parameters,
    df_daily=df_before_mmm,
    true_lambda_decay=true_lambda_decay
)
# Out:
# Applied geometric adstock to all channels: Done!

# %%
df_adstock.head()
# Out:
#         DATE  sum_n_Programmatic_imps_this_day  \
# 0 2020-01-01                      3.474373e+07
# 1 2020-01-02                      2.467451e+07
# 2 2020-01-03                      2.206128e+07
# 3 2020-01-04                      2.380538e+07
# 4 2020-01-05                      4.161635e+07
#
#    sum_n_Google.SEM_imps_this_day  sum_n_TikTok_imps_this_day  \
# 0                    5.659119e+06                5.654821e+06
# 1                    7.259378e+06                5.200713e+06
# 2                    3.674833e+06                3.042234e+06
# 3                    3.048467e+06                4.759823e+06
# 4                    6.458023e+06                8.822863e+06
#
#    sum_n_SEO.Non.Brand_imps_this_day  sum_n_Facebook_imps_this_day  \
# 0                       2.500215e+06                  5.499462e+06
# 1                       7.901119e+06                  4.305324e+06
# 2                       4.773498e+06                  5.707378e+06
# 3                       5.598131e+06                  2.666085e+06
# 4                       1.107352e+07                  4.737718e+06
#
#    sum_n_CRM_imps_this_day  sum_n_Affiliates_imps_this_day  \
# 0             1.251999e+06                    4.535888e+05
# 1             1.042125e+06                    2.952186e+06
# 2             6.415441e+05                    8.957170e+05
# 3             9.140373e+05                    1.741163e+06
# 4             9.592756e+05                    1.729475e+06
#
#    sum_n_Direct_sessions_this_day  sum_n_Unassigned_sessions_this_day  ...  \
# 0                    11595.747425                        10490.666620  ...
# 1                    11631.900390                         9884.142587  ...
# 2                    10917.796677                         8023.489039  ...
# 3                     8880.526100                         8373.874793  ...
# 4                    10228.282925                         7679.995451  ...
#
#    cvr_Unassigned_this_day  sum_n_Programmatic_imps_this_day_adstocked  \
# 0                 0.007873                                3.474373e+07
# 1                 0.010910                                2.814888e+07
# 2                 0.007525                                2.487617e+07
# 3                 0.008682                                2.629300e+07
# 4                 0.008717                                4.424565e+07
#
#    sum_n_Google.SEM_imps_this_day_adstocked  \
# 0                              5.659119e+06
# 1                              8.391202e+06
# 2                              5.353074e+06
# 3                              4.119081e+06
# 4                              7.281840e+06
#
#    sum_n_TikTok_imps_this_day_adstocked  \
# 0                          5.654821e+06
# 1                          6.897160e+06
# 2                          5.111382e+06
# 3                          6.293238e+06
# 4                          1.071083e+07
#
#    sum_n_SEO.Non.Brand_imps_this_day_adstocked  \
# 0                                 2.500215e+06
# 1                                 8.276151e+06
# 2                                 6.014920e+06
# 3                                 6.500369e+06
# 4                                 1.204857e+07
#
#    sum_n_Facebook_imps_this_day_adstocked  sum_n_CRM_imps_this_day_adstocked  \
# 0                            5.499462e+06                       1.251999e+06
# 1                            5.680189e+06                       1.167325e+06
# 2                            7.127425e+06                       7.582766e+05
# 3                            4.447941e+06                       9.898650e+05
# 4                            5.849703e+06                       1.058262e+06
#
#    sum_n_Affiliates_imps_this_day_adstocked  \
# 0                              4.535888e+05
# 1                              2.974865e+06
# 2                              1.044460e+06
# 3                              1.793386e+06
# 4                              1.819144e+06
#
#    sum_n_Direct_sessions_this_day_adstocked  \
# 0                              11595.747425
# 1                              13951.049875
# 2                              13708.006652
# 3                              11622.127430
# 4                              12552.708411
#
#    sum_n_Unassigned_sessions_this_day_adstocked
# 0                                  10490.666620
# 1                                  10933.209249
# 2                                   9116.809963
# 3                                   9285.555789
# 4                                   8608.551030
#
# [5 rows x 37 columns]

# %%
df_adstock.columns
# Out:
# Index(['DATE', 'sum_n_Programmatic_imps_this_day',
#        'sum_n_Google.SEM_imps_this_day', 'sum_n_TikTok_imps_this_day',
#        'sum_n_SEO.Non.Brand_imps_this_day', 'sum_n_Facebook_imps_this_day',
#        'sum_n_CRM_imps_this_day', 'sum_n_Affiliates_imps_this_day',
#        'sum_n_Direct_sessions_this_day', 'sum_n_Unassigned_sessions_this_day',
#        'sum_spend_Programmatic_this_day', 'sum_spend_Google.SEM_this_day',
#        'sum_spend_TikTok_this_day', 'sum_spend_SEO.Non.Brand_this_day',
#        'sum_spend_Facebook_this_day', 'sum_spend_CRM_this_day',
#        'sum_spend_Affiliates_this_day', 'sum_spend_Direct_this_day',
#        'sum_spend_Unassigned_this_day', 'cvr_Programmatic_this_day',
#        'cvr_Google.SEM_this_day', 'cvr_TikTok_this_day',
#        'cvr_SEO.Non.Brand_this_day', 'cvr_Facebook_this_day',
#        'cvr_CRM_this_day', 'cvr_Affiliates_this_day', 'cvr_Direct_this_day',
#        'cvr_Unassigned_this_day', 'sum_n_Programmatic_imps_this_day_adstocked',
#        'sum_n_Google.SEM_imps_this_day_adstocked',
#        'sum_n_TikTok_imps_this_day_adstocked',
#        'sum_n_SEO.Non.Brand_imps_this_day_adstocked',
#        'sum_n_Facebook_imps_this_day_adstocked',
#        'sum_n_CRM_imps_this_day_adstocked',
#        'sum_n_Affiliates_imps_this_day_adstocked',
#        'sum_n_Direct_sessions_this_day_adstocked',
#        'sum_n_Unassigned_sessions_this_day_adstocked'],
#       dtype='object')

# %% [markdown]
# ## Applying Diminishing Returns to Media Variables

# %%
alpha = 2.0  # same alpha for all channels
gamma = {
    "Programmatic": 0.2, "Google.SEM": 0.2, "TikTok": 0.25,
    "SEO.Non.Brand": 0.25, "Facebook": 0.2, "CRM": 0.2, "Affiliates": 0.2,
    "Direct": 0.2, "Unassigned": 0.2
}

df_dimissing = apply_diminishing_returns(
    setup_variables=basic_parameters,
    df_adstock=df_adstock,
    alpha_saturation=alpha,
    gamma_saturation=gamma,   # can also pass a single float for all channels
    x_marginal=1e6            # or e.g., 1e6 to use a constant factor or None for no marginal effect
)
# Out:
# Apply diminishing marginal returns: Done!

# %%
df_dimissing.head()
# Out:
#         DATE  sum_n_Programmatic_imps_this_day  \
# 0 2020-01-01                      3.474373e+07
# 1 2020-01-02                      2.467451e+07
# 2 2020-01-03                      2.206128e+07
# 3 2020-01-04                      2.380538e+07
# 4 2020-01-05                      4.161635e+07
#
#    sum_n_Google.SEM_imps_this_day  sum_n_TikTok_imps_this_day  \
# 0                    5.659119e+06                5.654821e+06
# 1                    7.259378e+06                5.200713e+06
# 2                    3.674833e+06                3.042234e+06
# 3                    3.048467e+06                4.759823e+06
# 4                    6.458023e+06                8.822863e+06
#
#    sum_n_SEO.Non.Brand_imps_this_day  sum_n_Facebook_imps_this_day  \
# 0                       2.500215e+06                  5.499462e+06
# 1                       7.901119e+06                  4.305324e+06
# 2                       4.773498e+06                  5.707378e+06
# 3                       5.598131e+06                  2.666085e+06
# 4                       1.107352e+07                  4.737718e+06
#
#    sum_n_CRM_imps_this_day  sum_n_Affiliates_imps_this_day  \
# 0             1.251999e+06                    4.535888e+05
# 1             1.042125e+06                    2.952186e+06
# 2             6.415441e+05                    8.957170e+05
# 3             9.140373e+05                    1.741163e+06
# 4             9.592756e+05                    1.729475e+06
#
#    sum_n_Direct_sessions_this_day  sum_n_Unassigned_sessions_this_day  ...  \
# 0                    11595.747425                        10490.666620  ...
# 1                    11631.900390                         9884.142587  ...
# 2                    10917.796677                         8023.489039  ...
# 3                     8880.526100                         8373.874793  ...
# 4                    10228.282925                         7679.995451  ...
#
#    sum_n_Unassigned_sessions_this_day_adstocked  \
# 0                                  10490.666620
# 1                                  10933.209249
# 2                                   9116.809963
# 3                                   9285.555789
# 4                                   8608.551030
#
#    sum_n_Programmatic_imps_this_day_adstocked_decay_diminishing  \
# 0                                      104091.549289
# 1                                       84333.498772
# 2                                       74528.513807
# 3                                       78773.324141
# 4                                      132559.116050
#
#    sum_n_Google.SEM_imps_this_day_adstocked_decay_diminishing  \
# 0                                      186434.976011
# 1                                      276441.183706
# 2                                      176352.566580
# 3                                      135699.717754
# 4                                      239894.167068
#
#    sum_n_TikTok_imps_this_day_adstocked_decay_diminishing  \
# 0                                      191878.777712
# 1                                      234033.697195
# 2                                      173438.878895
# 3                                      213541.476302
# 4                                      363438.893826
#
#    sum_n_SEO.Non.Brand_imps_this_day_adstocked_decay_diminishing  \
# 0                                      111627.261778
# 1                                      369505.832344
# 2                                      268548.517757
# 3                                      290222.388928
# 4                                      537933.275339
#
#    sum_n_Facebook_imps_this_day_adstocked_decay_diminishing  \
# 0                                      260487.419779
# 1                                      269047.717891
# 2                                      337597.460973
# 3                                      210681.094586
# 4                                      277076.924827
#
#    sum_n_CRM_imps_this_day_adstocked_decay_diminishing  \
# 0                                      922973.971669
# 1                                      860551.809805
# 2                                      559001.475204
# 3                                      729728.444424
# 4                                      780150.794817
#
#    sum_n_Affiliates_imps_this_day_adstocked_decay_diminishing  \
# 0                                       1.606189e+05
# 1                                       1.053420e+06
# 2                                       3.698505e+05
# 3                                       6.350501e+05
# 4                                       6.441713e+05
#
#    sum_n_Direct_sessions_this_day_adstocked_decay_diminishing  \
# 0                                       11594.505496
# 1                                       13949.555688
# 2                                       13706.538495
# 3                                       11620.882675
# 4                                       12551.363989
#
#    sum_n_Unassigned_sessions_this_day_adstocked_decay_diminishing
# 0                                       10489.824690
# 1                                       10932.331802
# 2                                        9116.078292
# 3                                        9284.810575
# 4                                        8607.860149
#
# [5 rows x 46 columns]

# %%
# For an impressions channel
plot_channel_transforms(df_dimissing, channel="Facebook", figsize=(900, 600))

# %% [markdown]
# # Calculating Conversions

# %%
df_dimissing.filter(regex=r"^cvr_")
# Out:
#      cvr_Programmatic_this_day  cvr_Google.SEM_this_day  cvr_TikTok_this_day  \
# 0                     0.002933                 0.021271             0.006831
# 1                     0.004294                 0.020190             0.000898
# 2                     0.002499                 0.020061             0.005767
# 3                     0.003415                 0.019625             0.008345
# 4                     0.003667                 0.021851             0.006631
# ..                         ...                      ...                  ...
# 725                   0.003264                 0.019873             0.009577
# 726                   0.004273                 0.018019             0.005726
# 727                   0.002459                 0.017397             0.002847
# 728                   0.003563                 0.019712             0.002996
# 729                   0.001460                 0.022627             0.006942
#
#      cvr_SEO.Non.Brand_this_day  cvr_Facebook_this_day  cvr_CRM_this_day  \
# 0                         0.002               0.005060          0.001900
# 1                         0.002               0.006877          0.006761
# 2                         0.002               0.005568          0.003372
# 3                         0.002               0.005322          0.007349
# 4                         0.002               0.005691          0.003052
# ..                          ...                    ...               ...
# 725                       0.002               0.006011          0.000000
# 726                       0.002               0.007962          0.007211
# 727                       0.002               0.006642          0.005850
# 728                       0.002               0.007128          0.004527
# 729                       0.002               0.006594          0.005558
#
#      cvr_Affiliates_this_day  cvr_Direct_this_day  cvr_Unassigned_this_day
# 0                      0.006             0.010037                 0.007873
# 1                      0.006             0.011229                 0.010910
# 2                      0.006             0.008940                 0.007525
# 3                      0.006             0.009098                 0.008682
# 4                      0.006             0.009796                 0.008717
# ..                       ...                  ...                      ...
# 725                    0.006             0.010148                 0.008956
# 726                    0.006             0.010442                 0.008530
# 727                    0.006             0.011895                 0.005246
# 728                    0.006             0.012151                 0.009163
# 729                    0.006             0.010982                 0.009626
#
# [730 rows x 9 columns]

# %%
df_conversion = calculate_conversions(setup_variables=basic_parameters, df_daily=df_dimissing)
# Out:
# Calculated conversions for all channel types: Done!

# %%
df_conversion
# Out:
#           DATE  sum_n_Programmatic_imps_this_day  \
# 0   2020-01-01                      3.474373e+07
# 1   2020-01-02                      2.467451e+07
# 2   2020-01-03                      2.206128e+07
# 3   2020-01-04                      2.380538e+07
# 4   2020-01-05                      4.161635e+07
# ..         ...                               ...
# 725 2021-12-26                      2.012568e+07
# 726 2021-12-27                      2.894618e+07
# 727 2021-12-28                      2.217193e+07
# 728 2021-12-29                      1.872012e+07
# 729 2021-12-30                      3.054856e+07
#
#      sum_n_Google.SEM_imps_this_day  sum_n_TikTok_imps_this_day  \
# 0                      5.659119e+06                5.654821e+06
# 1                      7.259378e+06                5.200713e+06
# 2                      3.674833e+06                3.042234e+06
# 3                      3.048467e+06                4.759823e+06
# 4                      6.458023e+06                8.822863e+06
# ..                              ...                         ...
# 725                    6.742164e+06                5.623130e+06
# 726                    7.052149e+06                4.791792e+06
# 727                    6.895407e+06                5.799029e+06
# 728                    8.650792e+06                3.080736e+06
# 729                    9.761977e+06                3.500346e+06
#
#      sum_n_SEO.Non.Brand_imps_this_day  sum_n_Facebook_imps_this_day  \
# 0                         2.500215e+06                  5.499462e+06
# 1                         7.901119e+06                  4.305324e+06
# 2                         4.773498e+06                  5.707378e+06
# 3                         5.598131e+06                  2.666085e+06
# 4                         1.107352e+07                  4.737718e+06
# ..                                 ...                           ...
# 725                       9.008119e+06                  5.888542e+06
# 726                       3.610471e+06                  6.185152e+06
# 727                       7.266563e+06                  9.839861e+06
# 728                       9.122573e+06                  4.024105e+06
# 729                       8.033885e+06                  5.227454e+06
#
#      sum_n_CRM_imps_this_day  sum_n_Affiliates_imps_this_day  \
# 0               1.251999e+06                    4.535888e+05
# 1               1.042125e+06                    2.952186e+06
# 2               6.415441e+05                    8.957170e+05
# 3               9.140373e+05                    1.741163e+06
# 4               9.592756e+05                    1.729475e+06
# ..                       ...                             ...
# 725             1.294745e+06                    7.539707e+05
# 726             3.911252e+05                    1.819834e+06
# 727             1.084049e+06                    1.336684e+06
# 728             5.915909e+05                    9.888391e+05
# 729             5.264493e+05                    2.023736e+06
#
#      sum_n_Direct_sessions_this_day  sum_n_Unassigned_sessions_this_day  ...  \
# 0                      11595.747425                        10490.666620  ...
# 1                      11631.900390                         9884.142587  ...
# 2                      10917.796677                         8023.489039  ...
# 3                       8880.526100                         8373.874793  ...
# 4                      10228.282925                         7679.995451  ...
# ..                              ...                                 ...  ...
# 725                     8557.408492                         9423.133242  ...
# 726                     9290.637382                        10811.311808  ...
# 727                     9763.710404                        10023.047965  ...
# 728                    12143.983475                        11169.383922  ...
# 729                     9651.884918                        10005.995445  ...
#
#      sum_n_Unassigned_sessions_this_day_adstocked_decay_diminishing  \
# 0                                         10489.824690
# 1                                         10932.331802
# 2                                          9116.078292
# 3                                          9284.810575
# 4                                          8607.860149
# ..                                                 ...
# 725                                       10388.571020
# 726                                       11849.301246
# 727                                       11207.173688
# 728                                       12289.204890
# 729                                       11234.112901
#
#      conv_Programmatic  conv_Google.SEM  conv_TikTok  conv_SEO.Non.Brand  \
# 0           305.349807      3965.709618  1310.663476          223.254524
# 1           362.132701      5581.351892   210.144582          739.011665
# 2           186.221025      3537.883187  1000.259292          537.097036
# 3           268.984140      2663.106951  1781.962838          580.444778
# 4           486.146400      5241.932352  2409.797688         1075.866551
# ..                 ...              ...          ...                 ...
# 725         220.197681      5138.210930  2553.721741          860.761835
# 726         399.434903      5118.040426  1388.987309          451.508152
# 727         186.316043      4940.229942   767.339439          716.587612
# 728         226.820272      6737.392484   555.386060          922.080347
# 729         142.959769      8823.483386  1210.707806          855.690792
#
#      conv_Facebook     conv_CRM  conv_Affiliates  conv_Direct  conv_Unassigned
# 0      1318.162509  1753.366764       963.713353   116.369227        82.584548
# 1      1850.264341  5817.935014      6320.520927   156.638858       119.273674
# 2      1879.693317  1884.829455      2219.103119   122.538303        68.594232
# 3      1121.201215  5362.545696      3810.300576   105.724587        80.610385
# 4      1576.873603  2381.168069      3865.028082   122.956208        75.036867
# ..             ...          ...              ...          ...              ...
# 725    2205.873978     0.000000      1980.580432   107.634446        93.041186
# 726    3063.063075  2824.334190      3965.522948   119.156304       101.079100
# 727    3734.652041  4903.840047      3038.250043   143.272308        58.791977
# 728    2360.603693  2354.056829      2252.840617   176.813652       112.611847
# 729    2178.773468  2446.040098      4412.355343   137.950473       108.140468
#
# [730 rows x 55 columns]

# %% [markdown]
# # Generate Final DataFrame

# %% [markdown]
# Add self-claim ratio for each channel

# %%
channels_impressions, channels_sessions
# Out:
# (['Programmatic',
#   'Google.SEM',
#   'TikTok',
#   'SEO.Non.Brand',
#   'Facebook',
#   'CRM',
#   'Affiliates'],
#  ['Direct', 'Unassigned'])

# %%
self_claim_config = {
    "Programmatic": 0.2,
    "TikTok": 0.3,
    "SEO.Non.Brand": -0.20,
    "CRM": 0.25,
    "Affiliates": -0.1,
    "Facebook": 0.05,
    "Google.SEM": 0.3,
    "Direct": -0.1,
    "Unassigned": 0.05
}


final_df = generate_final_df(
    setup_variables=basic_parameters,
    df_daily=df_conversion,
    df_baseline=df_baseline,
    self_claim_config=self_claim_config,
    daily_noise_std=0.02,  # ±2% daily noise
    seed=42
)
# Out:
# Generate final dataframe with self-claim + daily noise — Done!

# %%
final_df.columns
# Out:
# Index(['DATE', 'actual_impressions_Programmatic',
#        'self_impressions_Programmatic', 'actual_impressions_Google.SEM',
#        'self_impressions_Google.SEM', 'actual_impressions_TikTok',
#        'self_impressions_TikTok', 'actual_impressions_SEO.Non.Brand',
#        'self_impressions_SEO.Non.Brand', 'actual_impressions_Facebook',
#        'self_impressions_Facebook', 'actual_impressions_CRM',
#        'self_impressions_CRM', 'actual_impressions_Affiliates',
#        'self_impressions_Affiliates', 'actual_sessions_Direct',
#        'self_sessions_Direct', 'actual_sessions_Unassigned',
#        'self_sessions_Unassigned', 'actual_spend_Programmatic',
#        'self_spend_Programmatic', 'actual_spend_Google.SEM',
#        'self_spend_Google.SEM', 'actual_spend_TikTok', 'self_spend_TikTok',
#        'actual_spend_SEO.Non.Brand', 'self_spend_SEO.Non.Brand',
#        'actual_spend_Facebook', 'self_spend_Facebook', 'actual_spend_CRM',
#        'self_spend_CRM', 'actual_spend_Affiliates', 'self_spend_Affiliates',
#        'actual_spend_Direct', 'self_spend_Direct', 'actual_spend_Unassigned',
#        'self_spend_Unassigned', 'actual_conv_Programmatic',
#        'self_conv_Programmatic', 'actual_conv_Google.SEM',
#        'self_conv_Google.SEM', 'actual_conv_TikTok', 'self_conv_TikTok',
#        'actual_conv_SEO.Non.Brand', 'self_conv_SEO.Non.Brand',
#        'actual_conv_Facebook', 'self_conv_Facebook', 'actual_conv_CRM',
#        'self_conv_CRM', 'actual_conv_Affiliates', 'self_conv_Affiliates',
#        'actual_conv_Direct', 'self_conv_Direct', 'actual_conv_Unassigned',
#        'self_conv_Unassigned', 'total_conv_from_ads', 'revenue_from_ads',
#        'baseline_revenue', 'total_revenue'],
#       dtype='object')

# %%
final_df.filter(regex=r"conv_")
# Out:
#      actual_conv_Programmatic  self_conv_Programmatic  actual_conv_Google.SEM  \
# 0                  305.349807              375.157910             3965.709618
# 1                  362.132701              428.512018             5581.351892
# 2                  186.221025              218.898387             3537.883187
# 3                  268.984140              322.435696             2663.106951
# 4                  486.146400              570.278673             5241.932352
# ..                        ...                     ...                     ...
# 725                220.197681              262.299022             5138.210930
# 726                399.434903              465.555483             5118.040426
# 727                186.316043              225.749606             4940.229942
# 728                226.820272              272.917231             6737.392484
# 729                142.959769              173.285243             8823.483386
#
#      self_conv_Google.SEM  actual_conv_TikTok  self_conv_TikTok  \
# 0             5022.696308         1310.663476       1687.629931
# 1             7512.113500          210.144582        273.971539
# 2             4662.421711         1000.259292       1281.160736
# 3             3440.487790         1781.962838       2338.949875
# 4             6683.890923         2409.797688       3134.509375
# ..                    ...                 ...               ...
# 725           6523.263905         2553.721741       3265.523479
# 726           6759.434585         1388.987309       1863.505715
# 727           6209.493424          767.339439        964.948262
# 728           8804.025177          555.386060        727.139487
# 729          11377.059260         1210.707806       1545.519775
#
#      actual_conv_SEO.Non.Brand  self_conv_SEO.Non.Brand  actual_conv_Facebook  \
# 0                   223.254524               178.618192           1318.162509
# 1                   739.011665               599.247968           1850.264341
# 2                   537.097036               438.579210           1879.693317
# 3                   580.444778               463.918314           1121.201215
# 4                  1075.866551               874.034349           1576.873603
# ..                         ...                      ...                   ...
# 725                 860.761835               707.493381           2205.873978
# 726                 451.508152               369.628516           3063.063075
# 727                 716.587612               585.482695           3734.652041
# 728                 922.080347               720.104307           2360.603693
# 729                 855.690792               684.973536           2178.773468
#
#      self_conv_Facebook  actual_conv_CRM  self_conv_CRM  \
# 0           1418.241348      1753.366764    2118.245453
# 1           1953.804106      5817.935014    7385.703716
# 2           1996.014586      1884.829455    2364.602098
# 3           1144.843580      5362.545696    6711.556668
# 4           1719.647935      2381.168069    2930.593134
# ..                  ...              ...            ...
# 725         2329.373237         0.000000       0.000000
# 726         3083.543475      2824.334190    3379.237765
# 727         3828.248460      4903.840047    6145.683130
# 728         2460.585679      2354.056829    2959.770366
# 729         2255.603873      2446.040098    3046.086684
#
#      actual_conv_Affiliates  self_conv_Affiliates  actual_conv_Direct  \
# 0                963.713353            840.316844          116.369227
# 1               6320.520927           5715.779887          156.638858
# 2               2219.103119           2005.266153          122.538303
# 3               3810.300576           3364.011382          105.724587
# 4               3865.028082           3380.039933          122.956208
# ..                      ...                   ...                 ...
# 725             1980.580432           1842.770769          107.634446
# 726             3965.522948           3569.359303          119.156304
# 727             3038.250043           2755.636699          143.272308
# 728             2252.840617           2015.452870          176.813652
# 729             4412.355343           3926.112456          137.950473
#
#      self_conv_Direct  actual_conv_Unassigned  self_conv_Unassigned  \
# 0          105.959308               82.584548             85.686959
# 1          140.474601              119.273674            123.650565
# 2          111.015421               68.594232             73.483650
# 3           95.980385               80.610385             84.881462
# 4          111.270253               75.036867             78.361815
# ..                ...                     ...                   ...
# 725         95.259223               93.041186             96.115581
# 726        107.616803              101.079100            106.591748
# 727        130.356426               58.791977             61.647223
# 728        159.936270              112.611847            116.491923
# 729        127.109525              108.140468            113.831811
#
#      total_conv_from_ads
# 0           10039.173825
# 1           21157.273654
# 2           11436.218965
# 3           15774.881165
# 4           17234.805820
# ..                   ...
# 725         13160.022229
# 726         17431.126406
# 727         18489.279452
# 728         15698.605800
# 729         20316.101603
#
# [730 rows x 19 columns]

# %%
# Conversions
plot_actual_vs_self_conversions(final_df, key="conversion", figsize=(900, 600))

# %%
# Activity (impressions + clicks + sessions)
plot_actual_vs_self_conversions(final_df, key="activity", sort_by="self")

# %% [markdown]
# # Save data

# %%
output_dir = "output"
output_file = os.path.join(output_dir, "mmm_data.csv")

# Create directory if not exists, then save
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

final_df.to_csv(output_file, index=False)
print(f"Saved file to: {output_file}")
# Out:
# Saved file to: output/mmm_data.csv
